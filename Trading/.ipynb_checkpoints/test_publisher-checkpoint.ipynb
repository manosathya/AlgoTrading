# %%
import asyncio
import random
from datetime import datetime
import redis.asyncio as redis
import nest_asyncio

nest_asyncio.apply()

num_test_streams = 3
pub_freq = 1
stream_max_len = 100

async def publish_test_data_for_stream(stream_index, redis_client):
    last_price = 100.0  # Starting price
    stream_key = f"test_{stream_index}"  # Using test_1, test_2, etc.

    while True:
        # Simulate large swings by adding more volatility
        change = random.uniform(-5, 5)  # Increased fluctuation range
        last_price = max(10, last_price + change)  # Keep price above zero

        # Force RSI boundary conditions sometimes
        if random.random() < 0.1:  
            last_price *= random.choice([0.85, 1.15])  # Big jumps 15% up or down

        # Create fake OHLC data
        data = {
            "symbol": "TEST",
            "timestamp": datetime.utcnow().isoformat(),
            "open": round(last_price - random.uniform(0.5, 2), 2),
            "high": round(last_price + random.uniform(0.5, 2), 2),
            "low": round(last_price - random.uniform(1, 3), 2),
            "close": round(last_price, 2),
            "volume": random.randint(100, 1000),
            "trade_count": random.randint(10, 50),
            "vwap": round(last_price + random.uniform(-1, 1), 2),
        }

        # Push data to Redis stream
        await redis_client.xadd(stream_key, data, maxlen=stream_max_len)
        print(f"Pushed to {stream_key}: {data}")

        await asyncio.sleep(pub_freq)  # Adjust frequency if needed

async def publish_test_data(num_streams=1):
    redis_client = redis.Redis(host='localhost', port=6379, decode_responses=True)

    # Create a list of tasks to run multiple streams concurrently
    tasks = []
    for stream_index in range(1, num_streams + 1):
        task = asyncio.create_task(publish_test_data_for_stream(stream_index, redis_client))
        tasks.append(task)

    # Run all the tasks concurrently
    await asyncio.gather(*tasks)


await publish_test_data(num_streams=num_test_streams)
# Out:
# C:\Users\Mano\AppData\Local\Temp\ipykernel_4208\200926913.py:29: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:11.747359', 'open': 100.29, 'high': 103.47, 'low': 99.6, 'close': 101.79, 'volume': 902, 'trade_count': 24, 'vwap': 101.39}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:11.747359', 'open': 102.55, 'high': 105.26, 'low': 102.83, 'close': 104.46, 'volume': 412, 'trade_count': 22, 'vwap': 104.61}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:11.749279', 'open': 94.89, 'high': 96.68, 'low': 94.4, 'close': 96.06, 'volume': 683, 'trade_count': 37, 'vwap': 95.07}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:12.768099', 'open': 103.05, 'high': 104.96, 'low': 101.31, 'close': 104.13, 'volume': 974, 'trade_count': 46, 'vwap': 104.87}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:12.768099', 'open': 96.71, 'high': 100.17, 'low': 97.37, 'close': 98.55, 'volume': 460, 'trade_count': 17, 'vwap': 98.45}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:12.768099', 'open': 103.87, 'high': 105.11, 'low': 103.48, 'close': 104.6, 'volume': 191, 'trade_count': 13, 'vwap': 104.56}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:13.783920', 'open': 106.85, 'high': 108.31, 'low': 106.26, 'close': 107.74, 'volume': 667, 'trade_count': 33, 'vwap': 106.85}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:13.783920', 'open': 98.95, 'high': 101.14, 'low': 98.02, 'close': 100.14, 'volume': 814, 'trade_count': 19, 'vwap': 100.04}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:13.783920', 'open': 101.36, 'high': 103.37, 'low': 99.66, 'close': 101.9, 'volume': 673, 'trade_count': 37, 'vwap': 101.37}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:14.798745', 'open': 92.98, 'high': 94.1, 'low': 92.51, 'close': 93.53, 'volume': 819, 'trade_count': 34, 'vwap': 93.83}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:14.798745', 'open': 101.47, 'high': 104.03, 'low': 99.6, 'close': 102.52, 'volume': 789, 'trade_count': 39, 'vwap': 103.08}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:14.798745', 'open': 97.25, 'high': 99.43, 'low': 96.41, 'close': 97.85, 'volume': 555, 'trade_count': 38, 'vwap': 98.1}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:15.812922', 'open': 100.57, 'high': 103.12, 'low': 98.65, 'close': 101.52, 'volume': 865, 'trade_count': 28, 'vwap': 101.06}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:15.812922', 'open': 102.15, 'high': 105.77, 'low': 102.85, 'close': 104.01, 'volume': 393, 'trade_count': 35, 'vwap': 104.76}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:15.812922', 'open': 94.45, 'high': 96.93, 'low': 92.34, 'close': 95.25, 'volume': 106, 'trade_count': 17, 'vwap': 94.42}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:16.829009', 'open': 97.52, 'high': 100.71, 'low': 97.19, 'close': 99.39, 'volume': 144, 'trade_count': 15, 'vwap': 99.44}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:16.829009', 'open': 121.31, 'high': 123.24, 'low': 121.12, 'close': 122.44, 'volume': 254, 'trade_count': 26, 'vwap': 122.22}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:16.829009', 'open': 95.88, 'high': 98.4, 'low': 94.93, 'close': 96.49, 'volume': 950, 'trade_count': 24, 'vwap': 96.57}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:17.829063', 'open': 118.44, 'high': 119.95, 'low': 117.41, 'close': 119.35, 'volume': 685, 'trade_count': 40, 'vwap': 119.3}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:17.829063', 'open': 98.54, 'high': 100.8, 'low': 97.22, 'close': 99.59, 'volume': 732, 'trade_count': 46, 'vwap': 100.35}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:17.829063', 'open': 96.11, 'high': 97.75, 'low': 94.71, 'close': 97.18, 'volume': 973, 'trade_count': 47, 'vwap': 97.07}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:18.843442', 'open': 118.59, 'high': 121.92, 'low': 117.56, 'close': 120.32, 'volume': 445, 'trade_count': 48, 'vwap': 120.87}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:18.845467', 'open': 92.73, 'high': 95.1, 'low': 90.87, 'close': 93.44, 'volume': 622, 'trade_count': 46, 'vwap': 94.02}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:18.843442', 'open': 93.29, 'high': 96.68, 'low': 93.41, 'close': 95.24, 'volume': 395, 'trade_count': 16, 'vwap': 95.74}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:19.858731', 'open': 117.29, 'high': 119.93, 'low': 116.58, 'close': 118.86, 'volume': 196, 'trade_count': 35, 'vwap': 118.86}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:19.858731', 'open': 91.09, 'high': 93.71, 'low': 90.38, 'close': 92.67, 'volume': 854, 'trade_count': 42, 'vwap': 91.84}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-18T12:31:19.858731', 'open': 95.36, 'high': 97.33, 'low': 95.11, 'close': 96.16, 'volume': 466, 'trade_count': 43, 'vwap': 95.92}
