# %%
import asyncio
import random
from datetime import datetime
import redis.asyncio as redis
import nest_asyncio

nest_asyncio.apply()

num_test_streams = 3
pub_freq = 1
stream_max_len = 100

async def publish_test_data_for_stream(stream_index, redis_client):
    last_price = 100.0  # Starting price
    stream_key = f"test_{stream_index}"  # Using test_1, test_2, etc.

    while True:
        # Simulate large swings by adding more volatility
        change = random.uniform(-5, 5)  # Increased fluctuation range
        last_price = max(10, last_price + change)  # Keep price above zero

        # Force RSI boundary conditions sometimes
        if random.random() < 0.1:  
            last_price *= random.choice([0.85, 1.15])  # Big jumps 15% up or down

        # Create fake OHLC data
        data = {
            "symbol": "TEST",
            "timestamp": datetime.datetime.now(datetime.UTC).isoformat(),
            "open": round(last_price - random.uniform(0.5, 2), 2),
            "high": round(last_price + random.uniform(0.5, 2), 2),
            "low": round(last_price - random.uniform(1, 3), 2),
            "close": round(last_price, 2),
            "volume": random.randint(100, 1000),
            "trade_count": random.randint(10, 50),
            "vwap": round(last_price + random.uniform(-1, 1), 2),
        }

        # Push data to Redis stream
        await redis_client.xadd(stream_key, data, maxlen=stream_max_len)
        print(f"Pushed to {stream_key}: {data}")

        await asyncio.sleep(pub_freq)  # Adjust frequency if needed

async def publish_test_data(num_streams=1):
    redis_client = redis.Redis(host='localhost', port=6379, decode_responses=True)

    # Create a list of tasks to run multiple streams concurrently
    tasks = []
    for stream_index in range(1, num_streams + 1):
        task = asyncio.create_task(publish_test_data_for_stream(stream_index, redis_client))
        tasks.append(task)

    # Run all the tasks concurrently
    await asyncio.gather(*tasks)


await publish_test_data(num_streams=num_test_streams)
# Out:
# C:\Users\Mano\AppData\Local\Temp\ipykernel_25204\200926913.py:29: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:25.794112', 'open': 96.2, 'high': 97.97, 'low': 94.43, 'close': 96.73, 'volume': 701, 'trade_count': 19, 'vwap': 97.61}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:25.794112', 'open': 95.99, 'high': 98.17, 'low': 94.16, 'close': 96.84, 'volume': 231, 'trade_count': 15, 'vwap': 96.43}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:25.794112', 'open': 96.57, 'high': 98.52, 'low': 94.4, 'close': 97.35, 'volume': 464, 'trade_count': 29, 'vwap': 97.46}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:26.814721', 'open': 91.14, 'high': 93.02, 'low': 90.95, 'close': 92.44, 'volume': 277, 'trade_count': 18, 'vwap': 92.95}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:26.814721', 'open': 83.15, 'high': 86.23, 'low': 81.45, 'close': 84.32, 'volume': 932, 'trade_count': 21, 'vwap': 84.2}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:26.814721', 'open': 91.61, 'high': 93.05, 'low': 89.73, 'close': 92.2, 'volume': 413, 'trade_count': 27, 'vwap': 92.42}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:27.823691', 'open': 95.55, 'high': 98.57, 'low': 94.83, 'close': 96.75, 'volume': 448, 'trade_count': 42, 'vwap': 96.92}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:27.823691', 'open': 78.38, 'high': 80.69, 'low': 77.83, 'close': 79.98, 'volume': 983, 'trade_count': 11, 'vwap': 79.76}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:27.823691', 'open': 93.06, 'high': 95.66, 'low': 90.9, 'close': 93.73, 'volume': 403, 'trade_count': 28, 'vwap': 93.44}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54

# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:42.936126', 'open': 120.9, 'high': 124.5, 'low': 121.69, 'close': 122.7, 'volume': 315, 'trade_count': 11, 'vwap': 122.58}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:42.936738', 'open': 61.62, 'high': 63.63, 'low': 60.35, 'close': 62.81, 'volume': 627, 'trade_count': 26, 'vwap': 63.23}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:43.943621', 'open': 121.67, 'high': 124.06, 'low': 121.18, 'close': 123.33, 'volume': 782, 'trade_count': 39, 'vwap': 123.71}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:43.943621', 'open': 73.97, 'high': 77.38, 'low': 74.06, 'close': 75.78, 'volume': 206, 'trade_count': 21, 'vwap': 75.71}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:43.943621', 'open': 61.75, 'high': 63.76, 'low': 59.69, 'close': 62.56, 'volume': 706, 'trade_count': 18, 'vwap': 62.74}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:44.949333', 'open': 120.5, 'high': 122.95, 'low': 120.63, 'close': 121.8, 'volume': 903, 'trade_count': 45, 'vwap': 121.67}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:44.949995', 'open': 76.92, 'high': 78.42, 'low': 76.35, 'close': 77.69, 'volume': 574, 'trade_count': 13, 'vwap': 77.69}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:44.949995', 'open': 60.57, 'high': 64.15, 'low': 59.77, 'close': 62.2, 'volume': 992, 'trade_count': 41, 'vwap': 62.62}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:45.954158', 'open': 76.68, 'high': 79.51, 'low': 76.9, 'close': 77.97, 'volume': 957, 'trade_count': 27, 'vwap': 77.26}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:45.954158', 'open': 118.85, 'high': 121.98, 'low': 118.03, 'close': 120.57, 'volume': 582, 'trade_count': 26, 'vwap': 120.59}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:45.954158', 'open': 65.33, 'high': 68.43, 'low': 64.53, 'close': 66.52, 'volume': 582, 'trade_count': 14, 'vwap': 67.11}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:46.956291', 'open': 120.91, 'high': 122.42, 'low': 119.78, 'close': 121.56, 'volume': 551, 'trade_count': 41, 'vwap': 122.16}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:46.956291', 'open': 81.28, 'high': 83.15, 'low': 79.19, 'close': 82.05, 'volume': 918, 'trade_count': 44, 'vwap': 82.87}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:46.956291', 'open': 61.23, 'high': 63.63, 'low': 61.74, 'close': 62.83, 'volume': 354, 'trade_count': 48, 'vwap': 62.03}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:47.963064', 'open': 119.03, 'high': 121.03, 'low': 117.79, 'close': 119.76, 'volume': 773, 'trade_count': 33, 'vwap': 120.45}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:47.963064', 'open': 65.4, 'high': 67.18, 'low': 64.32, 'close': 66.61, 'volume': 216, 'trade_count': 14, 'vwap': 65.87}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:47.963064', 'open': 80.98, 'high': 83.88, 'low': 80.03, 'close': 81.91, 'volume': 289, 'trade_count': 24, 'vwap': 82.63}
# Pushed to test_2: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:48.968332', 'open': 69.7, 'high': 71.66, 'low': 68.72, 'close': 70.48, 'volume': 418, 'trade_count': 36, 'vwap': 69.52}
# Pushed to test_1: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:48.968332', 'open': 76.78, 'high': 79.19, 'low': 75.9, 'close': 78.07, 'volume': 936, 'trade_count': 44, 'vwap': 77.19}
# Pushed to test_3: {'symbol': 'TEST', 'timestamp': '2025-03-20T00:54:48.968332', 'open': 122.52, 'high': 124.44, 'low': 120.82, 'close': 123.26, 'volume': 228, 'trade_count': 37, 'vwap': 122.71}
