# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

from modules.strategies import Base_RSI

# %%
strategy_configs = {
    'RSI': {
        'stream_key': 'alpaca',
        'tickers': ['AAPL','AMD','CSCO','GOOG','INTC','JNPR','META','MSFT','NFLX','NVDA','TSLA'],  # List of tickers to trade
        'n_hist': 15,  # Historical data to fetch
        'overbought_th': 85,  # Overbought threshold for RSI
        'close_th': 50,
        'oversold_th': 15,  # Oversold threshold for RSI
    },
    'test' : {
        'stream_key': 'test',
        'tickers': ['1','2','3'],  # List of tickers to trade
        'n_hist': 15,  # Historical data to fetch
        'overbought_th': 85,  # Overbought threshold for RSI
        'close_th': 50,
        'oversold_th': 15,  # Oversold threshold for RSI
    }
}

strategy_name = 'RSI'

strategy = Base_RSI(strategy_configs[strategy_name])

await strategy.run_multiple_subscribers()
# Out:
# Positions initialized: {'1': None, '2': None, '3': None}
# 0 1: |
# 0 2: |
# 0 3: |
# 150.01 29324.804 195
# 489.74 29324.804 60
# short: 3 qty: 60
# 63.45 29324.804 462
# 152.65 29324.804 192
# 60.5 29324.804 485
# 413.06 29324.804 71
# close short: 3
# 156.7 29324.804 187
# 415.29 29324.804 71
# 56.3 29324.804 521
# 153.64 29324.804 191
# 58.67 29324.804 500
# 412.13 29324.804 71
# 59.76 29324.804 491
# 177.7 29324.804 165
# 410.16 29324.804 71
# 64.14 29324.804 457
# 470.05 29324.804 62
# 175.74 29324.804 167
# 176.84 29324.804 166
# 471.32 29324.804 62
# 65.2 29324.804 450
# 471.38 29324.804 62
# 181.8 29324.804 161
# 67.81 29324.804 432
# 469.96 29324.804 62
# 58.9 29324.804 498
# 181.16 29324.804 162
# 178.12 29324.804 165
# 62.37 29324.804 470
# 470.16 29324.804 62
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[2], line 24
#      20 strategy_name = 'test'
#      22 strategy = Base_RSI(strategy_configs[strategy_name])
# ---> 24 await strategy.run_multiple_subscribers()
#
# File ~\My Docs\Algo Trading\Trading\modules\strategies.py:92, in BaseStrategy.run_multiple_subscribers(self)
#      90 for ticker in self.config['tickers']:
#      91     tasks.append(self.subscriber(ticker))
# ---> 92 await asyncio.gather(*tasks)
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\tasks.py:316, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     314         result = coro.send(None)
#     315     else:
# --> 316         result = coro.throw(exc)
#     317 except StopIteration as exc:
#     318     if self._must_cancel:
#     319         # Task is cancelled right before coro stops.
#
# File ~\My Docs\Algo Trading\Trading\modules\strategies.py:72, in BaseStrategy.subscriber(self, ticker)
#      70 # Switch to real-time streaming
#      71 while True:
# ---> 72     new_messages = await redis_client.xread({stream_key: last_id}, block=0)
#      73     for stream, entries in new_messages:
#      74         for entry_id, data in entries:
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\redis\asyncio\client.py:616, in Redis.execute_command(self, *args, **options)
#     614     await self._single_conn_lock.acquire()
#     615 try:
# --> 616     return await conn.retry.call_with_retry(
#     617         lambda: self._send_command_parse_response(
#     618             conn, command_name, *args, **options
#     619         ),
#     620         lambda error: self._disconnect_raise(conn, error),
#     621     )
#     622 finally:
#     623     if self.single_connection_client:
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\redis\asyncio\retry.py:59, in Retry.call_with_retry(self, do, fail)
#      57 while True:
#      58     try:
# ---> 59         return await do()
#      60     except self._supported_errors as error:
#      61         failures += 1
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\redis\asyncio\client.py:590, in Redis._send_command_parse_response(self, conn, command_name, *args, **options)
#     586 """
#     587 Send a command and parse the response
#     588 """
#     589 await conn.send_command(*args)
# --> 590 return await self.parse_response(conn, command_name, **options)
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\redis\asyncio\client.py:637, in Redis.parse_response(self, connection, command_name, **options)
#     635         options.pop(NEVER_DECODE)
#     636     else:
# --> 637         response = await connection.read_response()
#     638 except ResponseError:
#     639     if EMPTY_RESPONSE in options:
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\redis\asyncio\connection.py:549, in AbstractConnection.read_response(self, disable_decoding, timeout, disconnect_on_error, push_request)
#     545         response = await self._parser.read_response(
#     546             disable_decoding=disable_decoding, push_request=push_request
#     547         )
#     548     else:
# --> 549         response = await self._parser.read_response(
#     550             disable_decoding=disable_decoding
#     551         )
#     552 except asyncio.TimeoutError:
#     553     if timeout is not None:
#     554         # user requested timeout, return None. Operation can be retried
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\redis\_parsers\resp2.py:82, in _AsyncRESP2Parser.read_response(self, disable_decoding)
#      80     self._chunks.clear()
#      81 self._pos = 0
# ---> 82 response = await self._read_response(disable_decoding=disable_decoding)
#      83 # Successfully parsing a response allows us to clear our parsing buffer
#      84 self._clear()
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\redis\_parsers\resp2.py:90, in _AsyncRESP2Parser._read_response(self, disable_decoding)
#      87 async def _read_response(
#      88     self, disable_decoding: bool = False
#      89 ) -> Union[EncodableT, ResponseError, None]:
# ---> 90     raw = await self._readline()
#      91     response: Any
#      92     byte, response = raw[:1], raw[1:]
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\redis\_parsers\base.py:219, in _AsyncRESPBase._readline(self)
#     217 else:
#     218     tail = self._buffer[self._pos :]
# --> 219     data = await self._stream.readline()
#     220     if not data.endswith(b"\r\n"):
#     221         raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\streams.py:568, in StreamReader.readline(self)
#     566 seplen = len(sep)
#     567 try:
# --> 568     line = await self.readuntil(sep)
#     569 except exceptions.IncompleteReadError as e:
#     570     return e.partial
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\streams.py:660, in StreamReader.readuntil(self, separator)
#     657         raise exceptions.IncompleteReadError(chunk, None)
#     659     # _wait_for_data() will resume reading if stream was paused.
# --> 660     await self._wait_for_data('readuntil')
#     662 if isep > self._limit:
#     663     raise exceptions.LimitOverrunError(
#     664         'Separator is found, but chunk is longer than limit', isep)
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\streams.py:545, in StreamReader._wait_for_data(self, func_name)
#     543 self._waiter = self._loop.create_future()
#     544 try:
# --> 545     await self._waiter
#     546 finally:
#     547     self._waiter = None
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# CancelledError:
