# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

from modules.strategies import Base_RSI

# %%
strategy_configs = {
    'RSI_Strategy': {
        'stream_key': 'alpaca',
        'tickers': ['AAPL','AMD','CSCO','GOOG','INTC','JNPR','META','MSFT','NFLX','NVDA','TSLA'],  # List of tickers to trade
        'n_hist': 15,  # Historical data to fetch
        'overbought_th': 85,  # Overbought threshold for RSI
        'close_th': 50,
        'oversold_th': 15,  # Oversold threshold for RSI
    },
    'test' : {
        'stream_key': 'test',
        'tickers': ['1','2','3'],  # List of tickers to trade
        'n_hist': 15,  # Historical data to fetch
        'overbought_th': 85,  # Overbought threshold for RSI
        'close_th': 50,
        'oversold_th': 15,  # Oversold threshold for RSI
    }
}

strategy_name = 'alpaca'

strategy = Base_RSI(strategy_configs[strategy_name])

await strategy.run_multiple_subscribers()
# Out:
# Positions initialized: {'GOOG': 'long', '2': None, '3': None}
# 0 2: |
# 0 3: |
# 0 GOOG: |
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 24
#      20 strategy_name = 'test'
#      22 strategy = Base_RSI(strategy_configs[strategy_name])
# ---> 24 await strategy.run_multiple_subscribers()
#
# File ~\My Docs\Algo Trading\Trading\modules\strategies.py:90, in BaseStrategy.run_multiple_subscribers(self)
#      88 for ticker in self.config['tickers']:
#      89     tasks.append(self.subscriber(ticker))
# ---> 90 await asyncio.gather(*tasks)
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~\My Docs\Algo Trading\Trading\modules\strategies.py:71, in BaseStrategy.subscriber(self, ticker)
#      69 # Switch to real-time streaming
#      70 while True:
# ---> 71     new_messages = await redis_client.xread({stream_key: last_id}, block=0)
#      72     for stream, entries in new_messages:
#      73         for entry_id, data in entries:
#
# UnboundLocalError: cannot access local variable 'last_id' where it is not associated with a value
# short: 3
