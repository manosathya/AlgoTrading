# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

from strategies import Base_RSI

# %%
import json
strategy_configs = json.load(open("strategy_configs.txt"))
print(list(strategy_configs.keys()))
# Out:
# ['base_rsi']

# %%
strategy_name = 'base_rsi'
strategy_configs[strategy_name]['strategy'] = base_rsi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 strategy_name = 'base_rsi'
# ----> 2 strategy_configs[strategy_name]['strategy'] = base_rsi
#
# NameError: name 'base_rsi' is not defined

# %%
strategy_configs = {
    'RSI_Strategy': {
        'tickers': ['AAPL','AMD','CSCO','GOOG','INTC','JNPR','META','MSFT','NFLX','NVDA','TSLA'],  # List of tickers to trade
        'n_hist': 15,  # Historical data to fetch
        'overbought_th': 85,  # Overbought threshold for RSI
        'oversold_th': 15,  # Oversold threshold for RSI
    }
}

strategy_name = 'RSI_Strategy'

strategy = Base_RSI(strategy_configs[strategy_name])

await strategy.run_multiple_subscribers()
# Out:
# 0 GOOG: |
# 0 AAPL: |
