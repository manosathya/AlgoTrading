# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

from trading_helpers import place_market_order
from ohlc_consumers import gather_tickers

# %%
base_rsi.__name__
# Out:
# 'base_rsi'

# %%
strategy_name = 'base_rsi'
strategy_configs={strategy_name:{}}

strategy_configs[strategy_name]['tickers'] = ['AAPL','AMD','CSCO','GOOG','INTC','JNPR','META','MSFT','NFLX','NVDA','TSLA']
strategy_configs[strategy_name]['n_hist'] = 15

# %%
json.dump(strategy_configs, open("strategy_configs.txt",'w'))

# %%
import json
json.load(open("strategy_configs.txt"))
# Out:
# {'base_rsi': {'tickers': ['AAPL',
#    'AMD',
#    'CSCO',
#    'GOOG',
#    'INTC',
#    'JNPR',
#    'META',
#    'MSFT',
#    'NFLX',
#    'NVDA',
#    'TSLA'],
#   'n_hist': 15}}

# %%
await gather_tickers(strategy_configs[strategy_name])
# Out:
# 0 CSCO: |
# 0 NFLX: |
# 0 INTC: |
# 0 GOOG: |
# 0 NVDA: |
# 0 TSLA: |
# 0 AAPL: |
# 0 MSFT: |
# 0 JNPR: |
# 0 AMD: |
# 0 META: |
# sell TSLA
# sell AMD
# sell CSCO
# sell AMD
# sell JNPR
# sell AMD
# sell AMD
# sell GOOG
# sell AAPL
# sell JNPR
# sell TSLA
# sell MSFT
# sell TSLA
# sell AMD
# sell AAPL
# sell META
# sell JNPR
# sell META
# sell AAPL
# sell MSFT
# sell AMD
# sell TSLA
# sell AAPL
# sell CSCO
# sell META
# sell NFLX
# sell TSLA
# sell MSFT
# sell AMD
# sell NVDA
# sell META
# sell JNPR
# sell AAPL
# sell NVDA
# sell MSFT
# sell TSLA
# sell NFLX
# sell CSCO
# sell TSLA
# sell NVDA
# sell CSCO
# sell AAPL
# sell MSFT
# sell META
# sell JNPR
# sell AAPL
# sell META
# sell CSCO
# sell NVDA
# sell AAPL
# sell NVDA
# sell AAPL
# sell NVDA
# sell MSFT
# sell NVDA
# sell MSFT
# sell AAPL
# sell MSFT
# sell NVDA
# sell AAPL
# sell META
# sell JNPR
# sell TSLA
# sell MSFT
# sell META
# sell AAPL
# sell NVDA
# sell TSLA
# sell NVDA
# sell AAPL
# sell META
# sell MSFT
# sell TSLA
# ...
