# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

from ohlc_consumers import gather_tickers

from strategies import base_rsi

# %%
import json
strategy_configs = json.load(open("strategy_configs.txt"))
print(list(strategy_configs.keys()))
# Out:
# ['base_rsi']

# %%
strategy_name = 'base_rsi'
strategy_configs[strategy_name]['strategy'] = base_rsi

# %%
await gather_tickers(strategy_configs[strategy_name])
# Out:
# 0 MSFT: |
# 0 INTC: |
# 0 NVDA: |
# 0 TSLA: |
# 0 AAPL: |
# 0 GOOG: |
# 0 NFLX: |
# 0 AMD: |
# 0 META: |
# 0 CSCO: |
# 0 JNPR: |
# buy INTC
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 await gather_tickers(strategy_configs[strategy_name])
#
# File ~\My Docs\Algo Trading\Trading\ohlc_consumers.py:65, in gather_tickers(strategy_config)
#      63 for ticker in strategy_config['tickers']:
#      64     tasks.append(ohlc_consume(ticker, strategy_config))
# ---> 65 await asyncio.gather(*tasks)
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File ~\miniconda3\envs\Trading\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~\My Docs\Algo Trading\Trading\ohlc_consumers.py:54, in ohlc_consume(ticker, strategy_config)
#      51         progress_bar.set_postfix({"Status": "Streaming"})
#      52         progress_bar.colour = "#0cfade"
# ---> 54         await strategy_config['strategy'](df, ticker)
#      56 await asyncio.sleep(0)
#
# File ~\My Docs\Algo Trading\Trading\strategies.py:25, in base_rsi(df, ticker)
#      22 if rsi_value <= OVERSOLD_THRESH:
#      23     # Buy when RSI is below the oversold threshold (enter long position)
#      24     print('buy', ticker)
# ---> 25     await place_market_order(ticker,'buy')
#      27 elif rsi_value >= OVERBOUGHT_THRESH:
#      28     # Sell when RSI is above the overbought threshold (enter long position)
#      29     try:
#
# NameError: name 'place_market_order' is not defined
