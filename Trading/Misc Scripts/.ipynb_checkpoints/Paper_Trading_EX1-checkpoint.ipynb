# %%
import os 
import nest_asyncio

nest_asyncio.apply()

API_KEY = os.environ['API_KEY']
SECRET_KEY = os.environ['SECRET_KEY']

# %%
from alpaca.trading.client import TradingClient

trading_client = TradingClient(API_KEY,SECRET_KEY, paper=True)

SYMBOL = 'TSLA'
free_cash_perc = 0.1
OVERBOUGHT_THRESH = 70
OVERSOLD_THRESH = 30
CLOSE_POSITION_THRESH = 50

# %%
from alpaca.trading.requests import MarketOrderRequest

def place_market_order(side, val=None):
    if side == 'buy':
        
        order_data = MarketOrderRequest(
              symbol=symbol,
              notional=val,
              side=OrderSide.BUY)
        
        return trading_client.submit_order(order_data=order_data)
        
    elif side=='sell':
        
        return trading_client.close_position(SYMBOL)

# %%
from alpaca.trading.enums import OrderSide, TimeInForce
from pandas_ta.momentum import rsi
import pandas as pd

bars = []
has_position = False
is_long  = False
is_short = False
async def on_new_bar(bar):
   global bars
   global has_position
   bars.append({k: v for k, v in bar})
   print("New bar!")
   print(f"Bar # {len(bars)}")

   if len(bars)>=15: # Need at least 14 bars to calculate RSI_14
     # Get as Bars DataFrame
     df = pd.DataFrame(bars)
     df.set_index('timestamp',inplace=True)
     # Calculate Latest RSI
     rsi_value = rsi(df.close.iloc[-15:])[-1]
     print(f"RSI IS {rsi_value}")
     # Trading Logic
     if rsi_value<=OVERSOLD_THRESH and not has_position:
       val = float(trading_client.get_account().buying_power)*free_cash_perc
       place_market_order('buy', val)
       has_position = True
       is_long = True
     elif rsi_value>=OVERSOLD_THRESH and not has_position:
       place_market_order('sell')
       has_position = True
       is_long = False
     elif rsi_value>=CLOSE_POSITION_THRESH and is_long:
       has_position = False
       is_long = False
       place_market_order('sell')
     elif rsi_value<=CLOSE_POSITION_THRESH and is_short:
       val = float(trading_client.get_account().buying_power)*free_cash_perc
       has_position = False
       is_short = False
       place_market_order('buy', val)

# %%
from alpaca.data.live.stock import StockDataStream
stock_stream = StockDataStream(API_KEY,SECRET_KEY)

# %%
stock_stream.subscribe_bars(on_new_bar,SYMBOL)

# %%
df = pd.DataFrame(bars)
df.set_index('timestamp',inplace=True)
df.head()
# Out:
#                           symbol     open     high     low    close  volume  \
# timestamp
# 2025-03-12 18:03:00+00:00   TSLA  247.360  247.520  247.07  247.070  1877.0
# 2025-03-12 18:04:00+00:00   TSLA  246.965  247.045  246.79  247.000  3536.0
# 2025-03-12 18:05:00+00:00   TSLA  247.180  247.295  247.05  247.295  2463.0
# 2025-03-12 18:06:00+00:00   TSLA  247.120  247.120  246.54  246.630  3668.0
# 2025-03-12 18:07:00+00:00   TSLA  246.580  246.670  246.30  246.515  3166.0
#
#                            trade_count        vwap
# timestamp
# 2025-03-12 18:03:00+00:00         25.0  247.250882
# 2025-03-12 18:04:00+00:00         38.0  246.913332
# 2025-03-12 18:05:00+00:00         37.0  247.149260
# 2025-03-12 18:06:00+00:00         43.0  246.683854
# 2025-03-12 18:07:00+00:00         42.0  246.559811

# %%
rsi(df.close.iloc[-15:])[-1]
# Out:
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\365313174.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi(df.close.iloc[-15:])[-1]
# 59.64417098419656

# %%
stock_stream.run()
# Out:
# New bar!
# Bar # 1
# New bar!
# Bar # 2
# New bar!
# Bar # 3
# New bar!
# Bar # 4
# New bar!
# Bar # 5
# New bar!
# Bar # 6
# New bar!
# Bar # 7
# New bar!
# Bar # 8
# New bar!
# Bar # 9
# New bar!
# Bar # 10
# New bar!
# Bar # 11
# New bar!
# Bar # 12
# New bar!
# Bar # 13
# New bar!
# Bar # 14
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 15
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 16
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 17
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 18
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 19
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 20
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 21
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 22
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 23
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 24
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 25
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 26
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 27
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 28
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 29
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 30
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 31
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 32
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 33
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 34
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 35
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 36
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 37
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 38
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 39
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 40
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 41
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 42
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 43
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 44
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 45
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 46
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 47
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 48
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 49
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 50
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 51
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 52
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 53
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 54
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 55
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 56
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 57
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 58
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 59
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 60
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 61
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 62
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 63
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 64
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 65
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 66
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 67
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 68
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 69
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 70
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 71
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 72
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 73
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 74
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 75
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 76
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 77
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 78
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 79
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 80
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 81
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 82
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 83
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 84
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 85
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 86
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 87
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 88
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 89
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 90
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 91
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 92
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 93
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 94
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 95
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 96
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 97
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 98
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 99
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 100
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 101
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 102
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 103
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 104
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 105
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 106
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 107
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 108
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 109
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 110
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 111
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 112
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 113
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 114
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 115
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# New bar!
# Bar # 116
# RSI IS nan
# C:\Users\Mano\AppData\Local\Temp\ipykernel_5564\4150589563.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rsi_value = rsi(df.close.tail(14))[0]
# keyboard interrupt, bye
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stock_stream.run()
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\alpaca\data\live\websocket.py:371, in DataStream.run(self)
#     369     pass
#     370 finally:
# --> 371     self.stop()
#
# File ~\miniconda3\envs\Trading\Lib\site-packages\alpaca\data\live\websocket.py:376, in DataStream.stop(self)
#     374 """Stops the websocket connection."""
#     375 if self._loop.is_running():
# --> 376     asyncio.run_coroutine_threadsafe(self.stop_ws(), self._loop).result(
#     377         timeout=5
#     378     )
#
# File ~\miniconda3\envs\Trading\Lib\concurrent\futures\_base.py:458, in Future.result(self, timeout)
#     456             return self.__get_result()
#     457         else:
# --> 458             raise TimeoutError()
#     459 finally:
#     460     # Break a reference cycle with the exception in self._exception
#     461     self = None
#
# TimeoutError:
